# %%
import math
import numpy as np

Q=np.array([1,2,3,4])
K=np.array([0,0.5,1,1.5])
# V=[5,4,5,4,5,4]
scale=3

diff=abs(np.sum(Q-K))
print(diff)
S=math.e**(-scale*diff)

print(S)
# Out:
# 7.0
# 7.582560427911915e-10

# %%
import math

print(math.e**(-12))
# Out:
# 6.144212353328214e-06
