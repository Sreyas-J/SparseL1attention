# %%
import math

Q=[10,9,3,4,2,3]
K=[2,3,2,3,1.5,2.5]
V=[5,4,5,4,5,4]

for i,q in enumerate(Q):
    print("Q: ",q,"K: ",K[i],"V: ",V[i])
    S=math.e**(q-K[i])
    print("S: ",S)
    print("Z: ",V[i]*S)
    print("--------------------------")
# Out:
# Q:  10 K:  2 V:  5
# S:  2980.957987041727
# Z:  14904.789935208635
# --------------------------
# Q:  9 K:  3 V:  4
# S:  403.428793492735
# Z:  1613.71517397094
# --------------------------
# Q:  3 K:  2 V:  5
# S:  2.718281828459045
# Z:  13.591409142295225
# --------------------------
# Q:  4 K:  3 V:  4
# S:  2.718281828459045
# Z:  10.87312731383618
# --------------------------
# Q:  2 K:  1.5 V:  5
# S:  1.6487212707001282
# Z:  8.243606353500642
# --------------------------
# Q:  3 K:  2.5 V:  4
# S:  1.6487212707001282
# Z:  6.594885082800513
# --------------------------

# %%
import math

print(math.e**4)
# Out:
# 54.59815003314423
